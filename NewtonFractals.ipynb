# %% [markdown]
# #Lab 7
# By:
# * Diaz Obando, Andres David
# * Gonzalez Ordoñez, Danier Elian
# * Mojica Perdigon, Gustavo Adolfo
#
# *From:  https://github.com/gjhernandezp/algorithms/blob/master/NewtonFractals/newtonfractalz3_1.ipynb*

# %% [markdown]
# Modify the newtonfractalz3_1  from github and add cells to plot and analyze 3 of the fractals shown in wikipedia

# %%
# Libraries
import math
import matplotlib.pyplot as plt
import numpy as np
import cmath

# %% [markdown]
# ## Fractal: $p(z)=z^{3}-2z+2$

# %%
def f(z):
    return z ** 3 - 2 * z + 2

def df(z):
    return 3 * z**2 - 2

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=255):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = -1.76929
    r2 = complex(0.884646,0.589743)
    r3 = complex(0.884646,-0.589743)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color -green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z**3-2*z+2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
#Plot the function

# Createing vectors X and Y 
x = np.linspace(-2.0, 2.0, 100) 
y = x ** 3 - 2 * x + 2
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X^3 - 2X +2', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot Y = X^3 - 2X +2') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
#Plot Newton Fractal Zoom Out

print("zoom out")
display1(zoom=1)
display1(zoom=5)
display1(zoom=10)
display1(zoom=15)
display1(zoom=20)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -7.5 , -7.5 ) to ( 7.5 , 7.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -10.0 , -10.0 ) to ( 10.0 , 10.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Plot Newton Fractal Zoom In
print("zoom in")
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/3)
display1(zoom=1/4)
display1(zoom=1/5)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )

# %%
#Plot Newton iterates

textExample = 'Newton iterates form z=10.0 + 0.0j'
print(textExample)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 + 10.0j'
print(textExample)
z=-10.0 +10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 -10.0j'
print(textExample)

z=-10.0 -10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=0.0 + 0.0j'
print(textExample)
z=0.0 + 0.0j
r=[]
i=[]
for k in range(100):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=-10.0 + 10.0j
# Newton iterates form z=-10.0 -10.0j
# Newton iterates form z=0.0 + 0.0j

# %% [markdown]
# ###Analysis

# %% [markdown]
# The function $p(z)=z^{3}-2z+2$ has a behavior in three sectors caused by complex roots and a real, but with points outside them due to their divergence in them. But the newton iterates has repetitive behaviors in the real set, undulatively when approaching the $0$ point, caused by the complex root that occurs here. Meanwhile on the other lines, its function about $0$ either exponentially negative or logarithmically

# %% [markdown]
# ## Fractal: $p(z)=\sin(z)$

# %%
def f(z):
    return cmath.sin(z)

def df(z):
    return cmath.cos(z)

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = -math.pi
    r2 = 0
    r3 = math.pi
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=sin(z)')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
#Plot the function


# Createing vectors X and Y 
x= np.arange(0.1,20,0.1)
y = np.sin(x)
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = sin(X)', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot Y = sin(x)') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
#Plot Newton Fractal Zoom Out

print("zoom out")
display1(zoom=3/2)
display1(zoom=5/2)
display1(zoom=7/2)
display1(zoom=9/2)
display1(zoom=11/2)
# Out:
# zoom out
# Z region from ( -0.75 , -0.75 ) to ( 0.75 , 0.75 )
# Z region from ( -1.25 , -1.25 ) to ( 1.25 , 1.25 )
# Z region from ( -1.75 , -1.75 ) to ( 1.75 , 1.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.25 , -2.25 ) to ( 2.25 , 2.25 )
# Z region from ( -2.75 , -2.75 ) to ( 2.75 , 2.75 )

# %%
#Plot Newton Fractal Zoom in
print("zoom in")
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/4)
display1(zoom=1/8)
display1(zoom=1/16)
display1(zoom=1/20)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.0625 , -0.0625 ) to ( 0.0625 , 0.0625 )
# Z region from ( -0.03125 , -0.03125 ) to ( 0.03125 , 0.03125 )
# Z region from ( -0.025 , -0.025 ) to ( 0.025 , 0.025 )

# %%
#Plot Newton iterates

textExample = 'Newton iterates form z=10.0 + 0.0j'
print(textExample)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 + 10.0j'
print(textExample)
z=-10.0 +10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 -10.0j'
print(textExample)

z=-10.0 -10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=0.0 + 0.0j'
print(textExample)
z=0.0 + 0.0j
r=[]
i=[]
for k in range(100):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=-10.0 + 10.0j
# Newton iterates form z=-10.0 -10.0j
# Newton iterates form z=0.0 + 0.0j

# %% [markdown]
# ###Analysis

# %% [markdown]
# The function $p(z) = sin(z)$ has fractals with repetitive behavior, caused by the amount of roots that ossify this wave function. In the meantime, newton iterations contain lines that come close to the $0$ point because their roots converge at that point, being these in logarithmic and exponential negative behaviors.

# %% [markdown]
# ## Fractal: $p(z)=z^{3}-z^{2}-z+1$

# %%
def f(z):
    return z**3 - z**2 - z + 1 

def df(z):
    return 3*z**2 -2*z - 1 

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r1)>=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z**3-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
#Plot the function

# Createing vectors X and Y 
x = np.linspace(-2.0, 2.0, 100) 
y = x ** 3 - x **2 - x + 1
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X^3 - X^2 - X + 1', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot Y = X^3 - X^2 - X + 1') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
#Plot Newton Fractal Zoom Out

print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
#Plot Newton Fractal Zoom In
print("zoom in")
display1(zoom=1)
display1(zoom=1/50)
display1(zoom=1/100)
display1(zoom=1/150)
display1(zoom=1/200)
display1(zoom=1/250)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.01 , -0.01 ) to ( 0.01 , 0.01 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0033333333333333335 , -0.0033333333333333335 ) to ( 0.0033333333333333335 , 0.0033333333333333335 )
# Z region from ( -0.0025 , -0.0025 ) to ( 0.0025 , 0.0025 )
# Z region from ( -0.002 , -0.002 ) to ( 0.002 , 0.002 )

# %%
#Plot Newton iterates

textExample = 'Newton iterates form z=10.0 + 0.0j'
print(textExample)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 + 10.0j'
print(textExample)
z=-10.0 +10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=-10.0 -10.0j'
print(textExample)

z=-10.0 -10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

textExample = 'Newton iterates form z=0.0 + 0.0j'
print(textExample)
z=0.0 + 0.0j
r=[]
i=[]
for k in range(100):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=-10.0 + 10.0j
# Newton iterates form z=-10.0 -10.0j
# Newton iterates form z=0.0 + 0.0j
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-111-82cf244b479c> in <module>()
#      63 for k in range(100):
#      64   dz = df(z)
# ---> 65   z = z - f(z) / dz # Newton iteration
#      66   r.append(np.real(z))
#      67   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# ###Analysis

# %% [markdown]
# The function $p(z)=z^{3}-z^{2}-z+1$ has a special behavior in its fractals, due to its only two real roots, which converge in a perfect circle in the center, while being away it behaves in a new way. The above states that your Newton interactions in the real and imaginary set, have motions close to the point $1$ and $-1$, which are their roots, all this if they have components in these sets, otherwise they act in a constant way around the point $0$
